# %% [markdown]
# # Классификация птиц
#
# В данном датасете исследуется принадлежность птицы к одной из шести базовых экологических ниш, такие как плавающие, поющие, хищные и.т.д. Логично ожидать, что от образа жизни птицы зависит строение её скелета. В датасете описываются 10 параметров, описывающих кости птиц - длина и ширина костей с непонятными латинскими названиями. Задача - предсказание экологической ниши (типа) птицы по этим параметрам.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('downloads/bird.csv', sep = ',', engine = 'python')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 0      0   80.78   6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70
# 1      1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50
# 2      2   79.97   6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31
# 3      3   77.65   5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78
# 4      4   62.80   4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88
# 5      5   61.92   4.78   50.46   3.47  49.52  4.41   56.95  2.73  29.07
# 6      6   79.73   5.94   67.39   4.50  42.07  3.41   71.26  3.56  37.22
# 7      7   86.98   5.68   74.52   4.55  44.46  3.78   76.02  3.81  37.94
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# ...

# %%
print(data)
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 0      0   80.78   6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70
# 1      1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50
# 2      2   79.97   6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31
# 3      3   77.65   5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78
# 4      4   62.80   4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88
# 5      5   61.92   4.78   50.46   3.47  49.52  4.41   56.95  2.73  29.07
# 6      6   79.73   5.94   67.39   4.50  42.07  3.41   71.26  3.56  37.22
# 7      7   86.98   5.68   74.52   4.55  44.46  3.78   76.02  3.81  37.94
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=420, step=1)

# %%
data.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
data.tail()
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 415   SO
# 416   SO
# 417   SO
# 418   SO
# 419   SO

# %% [markdown]
# Имеет смысл убрать столбец id

# %%
data = data.drop('id', axis=1)

# %%
data
# Out:
#        huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl   tarw  \
# 0     80.78   6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70   3.84
# 1     88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50   4.01
# 2     79.97   6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31   3.34
# 3     77.65   5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78   3.41
# 4     62.80   4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88   3.13
# 5     61.92   4.78   50.46   3.47  49.52  4.41   56.95  2.73  29.07   2.83
# 6     79.73   5.94   67.39   4.50  42.07  3.41   71.26  3.56  37.22   3.64
# 7     86.98   5.68   74.52   4.55  44.46  3.78   76.02  3.81  37.94   3.81
# 8    118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62   4.37
# 9    145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67   6.34
# 10   165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61   6.63
# ...

# %%
print(data.shape)
print(data.columns)
# Out:
# (420, 11)
# Index(['huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw',
#        'tarl', 'tarw', 'type'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=420, step=1)

# %%
data.at[2, 'type']
# Out:
# 'SW'

# %%
data['type']
# Out:
# 0      SW
# 1      SW
# 2      SW
# 3      SW
# 4      SW
# 5      SW
# 6      SW
# 7      SW
# 8      SW
# 9      SW
# 10     SW
# 11     SW
# 12     SW
# 13     SW
# 14     SW
# 15     SW
# 16     SW
# 17     SW
# 18     SW
# 19     SW
# 20     SW
# 21     SW
# 22     SW
# 23     SW
# 24     SW
# 25     SW
# 26     SW
# 27     SW
# 28     SW
# 29     SW
#        ..
# 390    SO
# 391    SO
# 392    SO
# 393    SO
# 394    SO
# 395    SO
# 396    SO
# 397    SO
# 398    SO
# 399    SO
# 400    SO
# 401    SO
# 402    SO
# 403    SO
# 404    SO
# 405    SO
# 406    SO
# 407    SO
# 408    SO
# 409    SO
# 410    SO
# 411    SO
# 412    SO
# 413    SO
# 414    SO
# 415    SO
# 416    SO
# 417    SO
# 418    SO
# 419    SO
# Name: type, Length: 420, dtype: object

# %%
data['type'][3]
# Out:
# 'SW'

# %%
data['type'].dtype.name
# Out:
# 'object'

# %%
type(data['type'])
# Out:
# pandas.core.series.Series

# %%
type(data['type'][3])
# Out:
# str

# %%
data[['huml', 'type']].head()
# Out:
#     huml type
# 0  80.78   SW
# 1  88.91   SW
# 2  79.97   SW
# 3  77.65   SW
# 4  62.80   SW

# %% [markdown]
# Итак, мы убедились - pandas работает и исправно выполняет команды

# %%
data.describe()
# Out:
#              huml        humw       ulnal       ulnaw        feml        femw  \
# count  419.000000  419.000000  417.000000  418.000000  418.000000  419.000000
# mean    64.650501    4.370573   69.115372    3.597249   36.872416    3.220883
# std     53.834549    2.854617   58.784775    2.186747   19.979082    2.023581
# min      9.850000    1.140000   14.090000    1.000000   11.830000    0.930000
# 25%     25.170000    2.190000   28.050000    1.870000   21.297500    1.715000
# 50%     44.180000    3.500000   43.710000    2.945000   31.130000    2.520000
# 75%     90.310000    5.810000   97.520000    4.770000   47.120000    4.135000
# max    420.000000   17.840000  422.000000   12.000000  117.070000   11.640000
#
#              tibl        tibw        tarl        tarw
# count  418.000000  419.000000  419.000000  419.000000
# mean    64.662823    3.182339   39.229976    2.930024
# std     37.838145    2.080827   23.184313    2.185673
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .05, figsize = (10, 10))
pass

# %%
data.corr()
# Out:
#            huml      humw     ulnal     ulnaw      feml      femw      tibl  \
# huml   1.000000  0.916572  0.976377  0.887025  0.771054  0.850474  0.826899
# humw   0.916572  1.000000  0.900770  0.957790  0.871023  0.936179  0.820093
# ulnal  0.976377  0.900770  1.000000  0.871604  0.759309  0.837922  0.761994
# ulnaw  0.887025  0.957790  0.871604  1.000000  0.826243  0.898133  0.797017
# feml   0.771054  0.871023  0.759309  0.826243  1.000000  0.944668  0.859952
# femw   0.850474  0.936179  0.837922  0.898133  0.944668  1.000000  0.868170
# tibl   0.826899  0.820093  0.761994  0.797017  0.859952  0.868170  1.000000
# tibw   0.869339  0.901478  0.818507  0.870392  0.904081  0.959632  0.928618
# tarl   0.695027  0.676207  0.653622  0.642814  0.832182  0.778986  0.922262
# tarw   0.751122  0.892047  0.737557  0.870590  0.869299  0.901852  0.736695
#
#            tibw      tarl      tarw
# huml   0.869339  0.695027  0.751122
# humw   0.901478  0.676207  0.892047
# ...

# %% [markdown]
# Ожидаемо, данные сильно коррелируют. Это происходит из-за того, что любой параметр кости птицы сильно коррелирует с размером самой птицы, а, как результат, и с остальными параметрами.

# %%
plt.plot(data['huml'], data['humw'], 'o', alpha = 0.05)
plt.xlabel('huml')
plt.ylabel('humw')
pass

# %%
data['type'] == 'SW'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# 400    False
# 401    False
# 402    False
# 403    False
# 404    False
# 405    False
# 406    False
# 407    False
# 408    False
# 409    False
# 410    False
# 411    False
# 412    False
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# Name: type, Length: 420, dtype: bool

# %%
plt.scatter(data[data['type'] == 'SW']['huml'],
            data[data['type'] == 'SW']['humw'],
            alpha = 0.15,
            label = 'SW',
            color = 'b')

plt.scatter(data[data['type'] == 'SO']['huml'],
            data[data['type'] == 'SO']['humw'],
            alpha = 0.05,
            label = 'SO',
            color = 'r')

plt.xlabel('huml')
plt.ylabel('humw')
plt.legend()
plt.grid()

# %%
np.random.seed(0)
education_num_rnd = data['humw'] + np.random.rand(data.shape[0]) - .5

plt.scatter(education_num_rnd[data['type'] == 'SW'],
            data[data['type'] == 'SW']['huml'],
            alpha = 0.15,
            label = 'SW',
            color = 'b')

plt.scatter(education_num_rnd[data['type'] == 'SO'],
            data[data['type'] == 'SO']['huml'],
            alpha = 0.15,
            label = 'SO',
            color = 'r')

plt.xlabel('huml')
plt.ylabel('humw')
plt.title('Fancy bones')
plt.grid()

# %%
plt.scatter(data[data['type'] == 'SW']['huml'],
            data[data['type'] == 'SW']['humw'],
            alpha = 0.15,
            label = 'SW',
            color = 'b')

plt.scatter(data[data['type'] == 'SO']['huml'],
            data[data['type'] == 'SO']['humw'],
            alpha = 0.15,
            label = 'SO',
            color = 'r')

plt.xlabel('huml')
plt.ylabel('humw')
plt.grid()

# %%
data.describe(include = ['object'])
# Out:
#        type
# count   420
# unique    6
# top      SO
# freq    128

# %%
data.describe(include = 'all')
# Out:
#               huml        humw       ulnal       ulnaw        feml  \
# count   419.000000  419.000000  417.000000  418.000000  418.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean     64.650501    4.370573   69.115372    3.597249   36.872416
# std      53.834549    2.854617   58.784775    2.186747   19.979082
# min       9.850000    1.140000   14.090000    1.000000   11.830000
# 25%      25.170000    2.190000   28.050000    1.870000   21.297500
# 50%      44.180000    3.500000   43.710000    2.945000   31.130000
# 75%      90.310000    5.810000   97.520000    4.770000   47.120000
# max     420.000000   17.840000  422.000000   12.000000  117.070000
#
#               femw        tibl        tibw        tarl        tarw type
# count   419.000000  418.000000  419.000000  419.000000  419.000000  420
# ...

# %% [markdown]
# Почему-то в числовых столбцах методы unique, top, freq не справились. Вероятно, это связано с числовым характером данных

# %%
data['type'].unique()
# Out:
# array(['SW', 'W', 'T', 'R', 'P', 'SO'], dtype=object)

# %%
#for name in data['class'].unique():
    #print(name, data['education-num'][data['education'] == name].iloc[0])

# %% [markdown]
# Аналога этой инструкции в нашем датасете нет, т.к. в нём лишь один столбец типа object

# %% [markdown]
# # Подготовка данных

# %%
data['type'].dtype.name
# Out:
# 'object'

# %%
data['humw'].dtype.name
# Out:
# 'float64'

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['type']
# ['huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw', 'tarl', 'tarw']

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# type ['SW' 'W' 'T' 'R' 'P' 'SO']

# %% [markdown]
# ## Обрабатываем пропущенные значения

# %% [markdown]
# Пропущенные данные заполняем либо медианой (для числовых значений), либо самым частым значением (для типа object).

# %%
data.median(axis = 0)
# Out:
# huml     44.180
# humw      3.500
# ulnal    43.710
# ulnaw     2.945
# feml     31.130
# femw      2.520
# tibl     52.120
# tibw      2.490
# tarl     31.740
# tarw      2.230
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data[numerical_columns].count(axis = 0)
# Out:
# huml     420
# humw     420
# ulnal    420
# ulnaw    420
# feml     420
# femw     420
# tibl     420
# tibw     420
# tarl     420
# tarw     420
# dtype: int64

# %%
data[categorical_columns].count(axis = 0)
# Out:
# type    420
# dtype: int64

# %%
data['type'].describe()
# Out:
# count     420
# unique      6
# top        SO
# freq      128
# Name: type, dtype: object

# %%
type(data['type'].describe())
# Out:
# pandas.core.series.Series

# %%
data['type'].describe().top
# Out:
# 'SO'

# %%
data['type'] = data['type'].fillna('SO')

# %%
data.describe(include = [object])
# Out:
#        type
# count   420
# unique    6
# top      SO
# freq    128

# %%
data_describe = data.describe(include = [object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %%
data.describe(include = [object])
# Out:
#        type
# count   420
# unique    6
# top      SO
# freq    128

# %% [markdown]
# ## Векторизация

# %% [markdown]
# Проводилась бы стандартно для столбца типа object. Вот только в объясняющих переменных все значения - числовые.

# %%
#binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
#nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
#print(binary_columns, nonbinary_columns)

# %%
#data['type'].unique()

# %% [markdown]
# Раскладываем столбец type на 6 dummy-столбцов.

# %%
#data_nonbinary = pd.get_dummies(data[nonbinary_columns])
#print(data_nonbinary.columns)

# %% [markdown]
# ## Нормализация количественных признаков
#
# Приводим все числовые значения к нулевому среднему и единичному среднеквадратичному отклонению:

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#              huml        humw       ulnal       ulnaw        feml        femw  \
# count  420.000000  420.000000  420.000000  420.000000  420.000000  420.000000
# mean    64.601762    4.368500   68.933905    3.594143   36.845071    3.219214
# std     53.779546    2.851524   58.613103    2.181985   19.935272    2.021455
# min      9.850000    1.140000   14.090000    1.000000   11.830000    0.930000
# 25%     25.205000    2.190000   28.132500    1.870000   21.332500    1.717500
# 50%     44.180000    3.500000   43.710000    2.945000   31.130000    2.520000
# 75%     90.220000    5.805000   97.205000    4.770000   47.100000    4.122500
# max    420.000000   17.840000  422.000000   12.000000  117.070000   11.640000
#
#              tibl        tibw        tarl        tarw
# count  420.000000  420.000000  420.000000  420.000000
# mean    64.603095    3.180690   39.212143    2.928357
# std     37.757629    2.078617   23.159515    2.183330
# ...

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#                huml          humw         ulnal         ulnaw          feml  \
# count  4.200000e+02  4.200000e+02  4.200000e+02  4.200000e+02  4.200000e+02
# mean   5.958197e-16 -1.111280e-15  5.966127e-16  8.194503e-16 -3.409971e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.018078e+00 -1.132201e+00 -9.356936e-01 -1.188891e+00 -1.254815e+00
# 25%   -7.325603e-01 -7.639773e-01 -6.961141e-01 -7.901716e-01 -7.781470e-01
# 50%   -3.797310e-01 -3.045739e-01 -4.303458e-01 -2.975010e-01 -2.866814e-01
# 75%    4.763565e-01  5.037656e-01  4.823340e-01  5.388932e-01  5.144113e-01
# max    6.608428e+00  4.724315e+00  6.023672e+00  3.852389e+00  4.024271e+00
#
#                femw          tibl          tibw          tarl          tarw
# count  4.200000e+02  4.200000e+02  4.200000e+02  4.200000e+02  4.200000e+02
# mean  -7.483432e-16 -2.460994e-16 -8.871211e-16  2.142466e-15 -1.362138e-15
# ...

# %% [markdown]
# ## Соединяем все в одну таблицу

# %%
data = pd.concat((data_numerical, data[categorical_columns]), axis = 1)
print(data.shape)
#print data.columns
# Out:
# (420, 11)

# %%
data.describe()
# Out:
#                huml          humw         ulnal         ulnaw          feml  \
# count  4.200000e+02  4.200000e+02  4.200000e+02  4.200000e+02  4.200000e+02
# mean   5.958197e-16 -1.111280e-15  5.966127e-16  8.194503e-16 -3.409971e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.018078e+00 -1.132201e+00 -9.356936e-01 -1.188891e+00 -1.254815e+00
# 25%   -7.325603e-01 -7.639773e-01 -6.961141e-01 -7.901716e-01 -7.781470e-01
# 50%   -3.797310e-01 -3.045739e-01 -4.303458e-01 -2.975010e-01 -2.866814e-01
# 75%    4.763565e-01  5.037656e-01  4.823340e-01  5.388932e-01  5.144113e-01
# max    6.608428e+00  4.724315e+00  6.023672e+00  3.852389e+00  4.024271e+00
#
#                femw          tibl          tibw          tarl          tarw
# count  4.200000e+02  4.200000e+02  4.200000e+02  4.200000e+02  4.200000e+02
# mean  -7.483432e-16 -2.460994e-16 -8.871211e-16  2.142466e-15 -1.362138e-15
# ...

# %% [markdown]
# # Выбор матрицы X и столбца y

# %%
X = data.drop(('type'), axis = 1)
y = data['type']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw',
#        'tarl', 'tarw'],
#       dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (420, 10)
# (420,)

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 294 126

# %% [markdown]
# # $k$NN

# %% [markdown]
# Метод k близжайших соседей. Т.к. датасет относительно небольшой, очень большие значения k выбирать не стоит

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.163265306122 0.238095238095

# %%
err_test = 1 - knn.score(X_test, y_test) # Альтернатиный метод подсчёта ошибки

# %%
err_test
# Out:
# 0.23809523809523814

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[ 9  0  3  0  0  0]
#  [ 0 12  3  0  0  0]
#  [ 0  0 44  0  0  0]
#  [ 0  1  2 26  2  0]
#  [ 2  2  0  0  2  0]
#  [ 1  1  4  9  0  3]]

# %% [markdown]
# ### Подбор параметров - долгий и муторный

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 2, 3, 4, 5, 10, 15, 20, 30, 40]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.149659863946 1

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.15873015873

# %% [markdown]
# ## SVC

# %% [markdown]
# Классификатор, основанный на машине опорных векторов.

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)

err_train = np.mean(y_train != svc.predict(X_train))
err_test  = np.mean(y_test  != svc.predict(X_test))

print(err_train, err_test)
# Out:
# 0.278911564626 0.309523809524

# %% [markdown]
# Покажем, как можно более аккуратно выполнять перебор параметров, не заводя массива напрямую. Очевидный недостаток любого такого переборного метода - считаться будет очень долго.

# %%
Cs = 10.**np.arange(-10, 10)
gamma_array = 10.**np.arange(-10, 10)

grid = GridSearchCV(svc, param_grid = {'C': Cs, 'gamma': gamma_array})
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_C = grid.best_estimator_.C

print(best_cv_err, best_C)
# Out:
# 0.132653061224 1000.0

# %% [markdown]
# Результат, как видно, улучшается приблизительно до результата, показанного kNN

# %% [markdown]
# ## Logistic

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)

err_train = np.mean(y_train != lr.predict(X_train))
err_test  = np.mean(y_test  != lr.predict(X_test))

print(err_train, err_test)
# Out:
# 0.255102040816 0.293650793651

# %% [markdown]
# Алгоритм не справляется с данными.

# %% [markdown]
# ## LDA и QDA

# %% [markdown]
# Т.к. нет оснований считать, что классы линейно или квадратично разделимы, можно предположить, что ошибка будет большой.

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
ld = LinearDiscriminantAnalysis()
ld.fit(X_train, y_train)

err_train = np.mean(y_train != ld.predict(X_train))
err_test  = np.mean(y_test  != ld.predict(X_test))

print(err_train, err_test)
# Out:
# 0.278911564626 0.293650793651

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
qd = QuadraticDiscriminantAnalysis()
qd.fit(X_train, y_train)

err_train = np.mean(y_train != qd.predict(X_train))
err_test  = np.mean(y_test  != qd.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0986394557823 0.214285714286

# %% [markdown]
# Предположение не оправдалось. QDA хорошо справляется с данной задачей. Возможно, это следует из некоторых физических соображений, связанных со строением птиц.

# %% [markdown]
# To be concluded...
